# %% [markdown]
# <a href="https://colab.research.google.com/github/JACKORARO12/Android-developer/blob/main/customer_churn_prediction__jack_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install matplotlib seaborn pandas

# %% [markdown]
# Retailrocket_customer_model Dataset

# %%
# Load the dataset
data1_df = pd.read_csv("/content/credit_card_churn.csv")
data2_df = pd.read_csv("/content/retailrocket_customer_model.csv")

print(data1_df.shape)
print(data2_df.shape)


data1_df.head(2)
data2_df.head(2)
# Out:
# (10127, 23)
# (2722, 231)
#    row_id  user_id  length_mean  start_year_mean  start_yearday_mean  \
# 0    1238   960004     97.77917           2015.0               157.0
# 1     148  1137634     48.86250           2015.0               149.0
#
#    start_month_mean  start_monthday_mean  start_week_mean  start_weekday_mean  \
# 0               6.0                  6.0             23.0                 7.0
# 1               5.0                 29.0             22.0                 6.0
#
#    start_isweekend_mean  ...  purchase_latent_factor5  \
# 0                   1.0  ...                      0.0
# 1                   0.0  ...                      0.0
#
#    purchase_latent_factor6  purchase_latent_factor7  purchase_latent_factor8  \
# 0                      0.0                      0.0                 0.000000
# 1                      0.0                      0.0                 0.823641
#
#    target_event  target_revenue  target_customer_value  time_step  \
# ...

# %%
# !pip install matplotlib seaborn pandas

# %%
data1 = pd.read_csv('/content/credit_card_churn.csv' )
data2 = pd.read_csv('/content/retailrocket_customer_model.csv')

# %%
data1_df.head()
data2_df.head()
# Out:
#    row_id  user_id  length_mean  start_year_mean  start_yearday_mean  \
# 0    1238   960004    97.779170           2015.0           157.00000
# 1     148  1137634    48.862500           2015.0           149.00000
# 2    1342   433067    17.000000           2015.0           150.33333
# 3    2122   354554     4.633333           2015.0           165.00000
# 4    2142   163561   160.104900           2015.0           143.97058
#
#    start_month_mean  start_monthday_mean  start_week_mean  start_weekday_mean  \
# 0          6.000000             6.000000        23.000000            7.000000
# 1          5.000000            29.000000        22.000000            6.000000
# 2          5.666666             9.666667        22.333334            5.000000
# 3          6.000000            14.000000        24.000000            1.000000
# 4          5.147059            19.411764        21.500000            3.852941
#
#    start_isweekend_mean  ...  purchase_latent_factor5  \
# ...

# %%
data2_df.columns
# Out:
# Index(['row_id', 'user_id', 'length_mean', 'start_year_mean',
#        'start_yearday_mean', 'start_month_mean', 'start_monthday_mean',
#        'start_week_mean', 'start_weekday_mean', 'start_isweekend_mean',
#        ...
#        'purchase_latent_factor5', 'purchase_latent_factor6',
#        'purchase_latent_factor7', 'purchase_latent_factor8', 'target_event',
#        'target_revenue', 'target_customer_value', 'time_step',
#        'target_customer_value_lag1', 'target_actual_profit'],
#       dtype='object', length=231)

# %%
len(data1_df)
# Out:
# 10127

# %%
data1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# # Histogram and Bar charts

# %%
#@title Histogram for 'Customer_Age'
plt.figure(figsize=(10, 6))
sns.histplot(data1['Customer_Age'], bins=20, color='skyblue', edgecolor='black', kde=True)
plt.title('Distribution of Customer Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#@title Pie chart for Gender
gender_counts = data1['Gender'].value_counts()
plt.figure(figsize=(8, 6))
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
#@title histogram
plt.figure(figsize=(10, 6))
sns.histplot(retail_df['start_month_mean'], bins=20, color='skyblue', edgecolor='black', kde=True)
plt.title('Distribution of start_month_mean')
plt.xlabel('start_month_mean')
plt.ylabel('Count')
plt.show()

# %%
#@title Bar chart for Education_Level, Marital_Status, and Income_Category
categorical_vars = ['Education_Level', 'Marital_Status', 'Income_Category']
for var in categorical_vars:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=data1[var], order=data1[var].value_counts().index, palette='viridis')
    plt.title(f'Distribution of {var}')
    plt.xlabel('Count')
    plt.show()

# %%
#@title 2. Scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(data=retail_df, x='start_week_mean', y='start_monthday_mean', hue='start_monthday_mean')
plt.title('start_week_mean vs start_monthly_mean')
plt.xlabel('start_monthday_mean')
plt.ylabel('start_week_mean')
plt.show()

# %%
data1_df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
#@title Box plot for Customer_Age by Education_Level
plt.figure(figsize=(10, 6))
sns.boxplot(x=data1['Education_Level'], y=data1['Customer_Age'], palette='viridis')
plt.title('Customer Age by Education Level')
plt.show()

# %%
#@title Box plot for Customer_Age by Marital_Status
plt.figure(figsize=(10, 6))
sns.boxplot(x=data1['Marital_Status'], y=data1['Customer_Age'], palette='viridis')
plt.title('Customer Age by Marital Status')
plt.show()

# %%
#@title Bar chart for 'Education_Level'
plt.figure(figsize=(12, 6))
sns.countplot(data=data1, x='Education_Level', hue='Attrition_Flag')
plt.title('Customer Education Level')
plt.xticks(rotation=45)
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Correlation Heatmap and Scatter Plot

# %% [markdown]
# 1. Histogram for 'Credit_Limit' and 'Months_on_book'

# %%
#@title 1. Histogram for 'year' and 'start_yesterday_mean'
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(data2['start_yearday_mean'], bins=30, edgecolor='k', alpha=0.7)
plt.title('')
plt.xlabel('start_yearday_mean')
plt.ylabel('year')

plt.subplot(1, 2, 2)
plt.hist(data2['start_month_mean'], bins=30, edgecolor='k', alpha=0.7)
plt.title('start_month_mean')
plt.xlabel('start_month_mean')
plt.ylabel('year')

plt.tight_layout()
plt.show()

# %%
#@title 2. Scatter plot for 'Credit_Limit' vs 'Total_Revolving_Bal for data1'

plt.figure(figsize=(12, 8))
sns.scatterplot(data=data2, x='start_yearday_mean', y='start_month_mean', hue='length_mean')
plt.title('')
plt.xlabel('Credit Limit')
plt.ylabel('Total Revolving Balance')
plt.show()

# %%
#@title 3. Correlation heatmap for continuous features
# Here, we'll assume the features you mentioned plus any others you might want to add
features = ['start_yearday_mean', 'start_month_mean', 'start_monthday_mean']
correlation_matrix = data2[features].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
#@title Correlation heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = data2.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Churn Information: Stacked Bar Chart :manipulation of data1

# %%
#@title Bar chart for 'Attrition_Flag'
data1['Attrition_Flag'].value_counts().plot(kind='bar')
plt.title('Distribution of Attrition_Flag')
plt.ylabel('Count')
plt.xlabel('Attrition Flag')
plt.show()

# %%
#@title Stacked bar chart for 'Attrition_Flag' with 'Education_Level'
education_churn = data1.groupby(['Education_Level', 'Attrition_Flag']).size().unstack()
education_churn.plot(kind='bar', stacked=True)
plt.title('Churn Distribution based on Education Level')
plt.ylabel('Count')
plt.xlabel('Education Level')
plt.show()

# %%
#@title Box plot for 'Attrition_Flag' with 'Credit_Limit'
data1.boxplot(column='Credit_Limit', by='Attrition_Flag')
plt.title('Credit Limit Distribution based on Churn')
plt.ylabel('Credit Limit')
plt.xlabel('Attrition Flag')
plt.suptitle('')  # Removes the auto-generated title for clarity
plt.show()

# %%
#@title Box plot for 'Attrition_Flag' with 'Total_Trans_Amt'
data1.boxplot(column='Total_Trans_Amt', by='Attrition_Flag')
plt.title('Total Transaction Amount Distribution based on Churn')
plt.ylabel('Total Transaction Amount')
plt.xlabel('Attrition Flag')
plt.suptitle('')  # Removes the auto-generated title for clarity
plt.show()

# %%
# Transforming 'Attrition_Flag' into a binary variable for simplicity
data1['Churned'] = data1['Attrition_Flag'].apply(lambda x: 1 if x == 'Attrited Customer' else 0)

# Stacked bar chart with 'Marital_Status'
churn_distribution = data1.groupby('Marital_Status')['Churned'].value_counts().unstack()
churn_distribution.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Churn Distribution based on Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Transaction Information: KDE Plot

# %%
#@title KDE plot for 'Total_Trans_Amt'
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data1, x='Total_Trans_Amt', hue='Attrition_Flag', fill=True)
plt.title('Kernel Density Estimation for Total Transaction Amount')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Density')
plt.show()

# %%
#@title KDE plot for 'Total_Trans_Ct'
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data1, x='Total_Trans_Ct', hue='Attrition_Flag', fill=True)
plt.title('Kernel Density Estimation for Total Transaction Count')
plt.xlabel('Total Transaction Count')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # Time-based Trends

# %%
#@title Plotting Transaction Amount over Months_Inactive_12_mon
Months_Inactive_12_mon_Total_Trans_Amt = data1.groupby('Months_Inactive_12_mon')['Total_Trans_Amt'].mean()

plt.figure(figsize=(12, 5))
Months_Inactive_12_mon_Total_Trans_Amt.plot(kind='line', marker='o', color='blue')
plt.title('Monthly Transaction Amount over Time')
plt.xlabel('Months Inactive_12_mon')
plt.ylabel('Transaction Amount')

# %%
#@title Plotting Churn Rate over Months_Inactive_12_mon
monthly_churn = data1.groupby('Months_Inactive_12_mon')['Churned'].mean()
# Plotting the results
plt.figure(figsize=(6, 5))
monthly_churn.plot(kind='line', marker='o', color='blue')
plt.title('Churn Rate over Months_Inactive_12_mon')
plt.xlabel('Months_Inactive_12_mon')
plt.ylabel('Churn Rate')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
#@title Plotting Transaction Amount over Months_on_book
monthly_Total_Trans_Amt = data1.groupby('Months_on_book')['Total_Trans_Amt'].mean()

plt.figure(figsize=(12, 5))
monthly_Total_Trans_Amt.plot(kind='line', marker='o', color='blue')
plt.title('Monthly Transaction Amount over Time')
plt.xlabel('Months on Book')
plt.ylabel('Transaction Amount')

# %%
#@title Plotting Churn Rate over Months_on_book
monthly_churn = data1.groupby('Months_on_book')['Churned'].mean()
# Plotting the results
plt.figure(figsize=(6, 5))
monthly_churn.plot(kind='line', marker='o', color='blue')
plt.title('Churn Rate over Months on Book')
plt.xlabel('Months on Book')
plt.ylabel('Churn Rate')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
#@title Selecting a subset of columns for the pair plot
cols = ['Customer_Age', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Revolving_Bal', 'Churned']
sns.pairplot(data1[cols], hue='Churned', height=2.5)
plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()

# %%
#@title Correlation between income and Card
plt.figure(figsize=(10,8))
sns.heatmap(pd.crosstab(data1['Income_Category'], data1['Card_Category']))
# Out:
# <Axes: xlabel='Card_Category', ylabel='Income_Category'>

# %%
#@title Distribution of month_inactive_12
import seaborn as sns
sns.histplot(data1['Months_Inactive_12_mon'],kde=True)

# %%
#@title Dependent count based on income category
plt.figure(figsize=(10,5))
sns.barplot(x=data1['Income_Category'], y=data1['Dependent_count'])

# %%
#@title Relationship between age and credit
data1.plot.scatter('Customer_Age', 'Credit_Limit')

# %%
#@title Income and credit limit
plt.figure(figsize=(12,15))
data1.plot.scatter('Income_Category', 'Credit_Limit')

# %%
data1.groupby('Income_Category').aggregate({'Card_Category':'value_counts'})

# %%
#@title The count of income category with respect to card category
plt.figure(figsize=(12,8))
sns.countplot(data=data1,x='Income_Category',hue='Card_Category')
plt.title('Income Category with respect to card category count plot')
plt.show()

# %%
#@title Grouping and aggregating
card_counts = data1.groupby('Income_Category').aggregate({'Card_Category':'value_counts'}).unstack()

# Plotting
card_counts.plot(kind='bar', stacked=True)
plt.title("Card Category Counts by Income Category")
plt.ylabel("Number of Customers")
plt.xlabel("Income Category")
plt.show()

# %%
df2=data1.groupby('Income_Category').aggregate({'Avg_Utilization_Ratio':'mean'})
cols=['Unknown','Less than $40K','$40K - $60K','$60K - $80K','$80K - $120K','$120K +']
plt.figure(figsize=(12,8))
sns.barplot(data=df2,x=df2.index,y=df2['Avg_Utilization_Ratio'],order=cols)
plt.title('Average_Card_Utlization Ratio with respect to card category')
plt.show()

# %%
cat_cols= list(data1.select_dtypes(object).columns)
cat_cols
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %%
num_cols= list(data1.select_dtypes(['int64','float64']).columns)
num_cols

# %%
#@title plotting boxplot representation for the categorical variable
reqd_cols=['Months_Inactive_12_mon','Total_Amt_Chng_Q4_Q1','Total_Trans_Amt','Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio','Credit_Limit']
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[0])
    plt.title(f'Boxplot with {reqd_cols[0]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[1])
    plt.title(f'Boxplot with {reqd_cols[1]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[2])
    plt.title(f'Boxplot with {reqd_cols[2]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[3])
    plt.title(f'Boxplot with {reqd_cols[3]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[4])
    plt.title(f'Boxplot with {reqd_cols[4]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[5])
    plt.title(f'Boxplot with {reqd_cols[5]} with {col} ')
    plt.show()
    print()
    print()

# %%
for col in cat_cols:
    plt.figure(figsize=(12,8))
    sns.boxplot(data=data1,x=col,y=reqd_cols[6])
    plt.title(f'Boxplot with {reqd_cols[6]} with {col} ')
    plt.show()
    print()
    print()

# %%
#@title plotting a scatter plot on credit utlization ratio and total_trans_amt
plt.figure(figsize=(12,8))
sns.scatterplot(data=data1,y='Avg_Utilization_Ratio',x='Total_Trans_Amt')

# %%
#@title plotting a scatter plot on credit utlization ratio and credit_limit
plt.figure(figsize=(12,8))
sns.scatterplot(data=data1,y='Avg_Utilization_Ratio',x='Credit_Limit')
plt.title('Plot between Average credit utilization and Credit Limit')

# %%
#@title Credit utlization and Total_Trans_Amt
plt.figure(figsize=(12,8))
sns.scatterplot(data=data1,x='Total_Trans_Amt',y='Credit_Limit')
plt.title('Plot between Total Transactional Amount and Credit Limit')

# %%
#@title Scatter plot between continous variables
#num_cols.remove('CLIENTNUM')
for i in num_cols:
    for j in num_cols:
        if i!=j:
            plt.figure(figsize=(12,8))
            sns.scatterplot(data=data1,x=i,y=j)
            plt.title(f'Scatter plot between {i} and {j}')
            plt.show()
            print()
            print()

# %%
#@title Correlation matrix

plt.figure(figsize=(16,6))
sns.heatmap(data1[num_cols].corr(),annot=True)
plt.title('Heatmap for the numerical features in data')
plt.show()

# %%
for i in num_cols:
    for col in cat_cols:
        fig,ax=plt.subplots(1,2)
        fig.set_figheight(8)
        fig.set_figwidth(20)
        fig.suptitle(f'Boxplot and violin plot for {i} with respect to {col}')
        #ax[0].set_title(f'Violinplot for {i} with respect to {col}')
        sns.violinplot(data=data1,x=col,y=i,ax=ax[0])
        #ax[1].set_title(f'Boxplot for {i} with respect to {col}')
        sns.boxplot(data=data1,x=col,y=i,ax=ax[1])
        plt.show()
        print()
        print()

# %%
#@title Distribution of dataset of attrited customers
attrited_df= data1[data1['Attrition_Flag']=='Attrited Customer']
plt.figure(figsize=(8,6))
sns.histplot(attrited_df['Customer_Age'],kde=True,stat='probability')
plt.title('Distribution of Age of customer for attrited data')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=attrited_df,x='Income_Category')
plt.title('Countplot for Income category for attrited class')
plt.show()

# %%
#@title Counting how mauch are females and males in attrtion dataset
plt.figure(figsize=(8,6))
sns.countplot(data=data1,x='Gender')
plt.title('Plot of count of genders for the Attrited data')
plt.show()

# %%
#@title The revolving balance for each card category in the dataset
plt.figure(figsize=(8,6))
sns.barplot(data=dataset1,x='Income_Category',y='Total_Revolving_Bal')
plt.title('Barplot for total revolving balance w.r.t Income category')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=dataset1,x='Income_Category',y='Credit_Limit')
plt.title('Barplot for credit limit w.r.t Income category')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=data1,x='Income_Category',y='Avg_Utilization_Ratio')
plt.title('Barplot for Avg_Utilization_Ratio w.r.t Income category')
plt.show()

# %%
num_cols.remove('CLIENTNUM')
for i in num_cols:
    plt.figure(figsize=(8,6))
    sns.histplot(attrited_df[i],stat='probability',kde=True)
    plt.title(f'Probability distribution on {i}')
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le_Education_Level = LabelEncoder()
le_Gender = LabelEncoder()
le_Income_Category = LabelEncoder()
le_Card_Category = LabelEncoder()
